# %%
import pandas as pd

final_db = pd.read_excel('Final formated DB.xlsx')
final_db = final_db.loc[final_db['Exclusion'] == 'No']
final_db = final_db.loc[final_db['Time point'] == 'M0']
final_db = final_db.set_index('Patient ID')

# %%
# Just to have everything at disposition to tweak if needed.
glucose_db = final_db.loc[final_db['Change of Insuline medication'] == 'NO']
cpept_db = glucose_db.loc[glucose_db['OGTT C peptide'] == 'Yes']
glu_db = glucose_db.loc[glucose_db['OGTT Glucose'] == 'Yes']
ins_db = glucose_db.loc[glucose_db['OGTT Insuline'] == 'Yes']

# %% [markdown]
# # Index correlations

# %%
# Some lists to make it easy to manipulate
Ins_indexes = ['AUC Insuline', 'AUC Glucose', 'AUC C peptide', 'Average Fasting Glucose',
               'Average Fasting Insulin', 'Average Fasting C peptide', 'HOMA ISI', 'Matsuda index',
               'Stumvoll First Phase', 'Stumvoll Second Phase', 'HOMA IR',
               'OGIS','IGI 30', 'IGI Cpept', 'CPRI', 'PCPRI','Trapezoid AUC Insuline', 'Trapezoid AUC C peptide',
               'Trapezoid AUC Glucose','Corrected AUC Insuline', 'Corrected AUC Glucose']
sec_indices = ['AUC Insuline','AUC C peptide',
              'Average Fasting Insulin', 'Average Fasting C peptide',
              'Stumvoll First Phase', 'Stumvoll Second Phase',
              'IGI 30', 'IGI Cpept', 'CPRI', 'PCPRI',
              'Trapezoid AUC Insuline', 'Trapezoid AUC C peptide','Corrected AUC Insuline']
sensitivity_indices = ['AUC Glucose', 'Average Fasting Glucose','Corrected AUC Glucose','Trapezoid AUC Glucose',
                       'HOMA ISI', 'Matsuda index', 'OGIS']
fasting_indices = ['Average Fasting Insulin','Average Fasting C peptide', 'Average Fasting Glucose',
                   'CPRI','HOMA ISI','HOMA IR']

OGTT_ins = ['AUC Insuline','Matsuda index','Stumvoll First Phase','Stumvoll Second Phase','OGIS','IGI 30'
           'Trapezoid AUC Insuline','Corrected AUC Insuline']
OGTT_cpept = ['AUC C peptide','IGI Cpept', 'PCPRI','Trapezoid AUC C peptide']
OGTT_glu = ['AUC Glucose','Corrected AUC Glucose']


import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

scatter_matrix(ins_db[Ins_indexes], figsize=(13,10))
plt.show()

# %% [markdown]
# We have way too much comparaisons to look at them all one by one.
#
# We want to find the best couples of index that illustrate the "hyperbolic relationship" between secretion of insulin and sensitivity
#
# # Log(x) against y  r² approach
#
# We calculate the r² the same manner Excel would do for logarythmic tendancy curve
#
# For example for Matsuda against stumvoll:

# %%
from analysis_script import correl_graph

correl_graph(ins_db, 'Matsuda index', 'Stumvoll First Phase')
plt.show()
# Out:
# C:\Users\Daph\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# We calculate here all those r-squared values for our desired variables

# %%
import scipy.stats
import numpy as np

def calculate_r_square_log_x(df, x, y):
    df = df[[x,y]].dropna()
    slope, intercept, r_value, d, e = scipy.stats.linregress(np.log(df[x]), df[y])
    return r_value**2

def log_r_square_df(df):
    r_df = pd.DataFrame(columns = df.columns, index= df.columns)
    for a in df.columns:
        for b in df.columns:
            if a == b: 
                r_df.loc[[a],[b]] = 1
            else:
                r_df.loc[[a],[b]] = calculate_r_square_log_x(df, a, b)
            
    return r_df

rsquare_df = log_r_square_df(ins_db[Ins_indexes])

# %% [markdown]
# We're not very interested to compare indices of the same "type" against each other but more to compare secretion against sensitivity. Let's clean our table:

# %%
rsquare_df.drop(index = sec_indices, inplace = True)
rsquare_df.drop(columns = sensitivity_indices, inplace = True)
rsquare_df.drop(index = ['HOMA IR'], inplace = True)

# Table of R-square
rsquare_df
# Out:
#                         AUC Insuline AUC C peptide Average Fasting Insulin  \
# AUC Glucose                0.0239595    0.00603264               0.0143691
# Average Fasting Glucose    0.0261497     0.0580752                0.190157
# HOMA ISI                    0.368708    0.00648124                0.869569
# Matsuda index               0.599299     0.0629211                0.672861
# OGIS                        0.357927      0.039208                0.202892
# Trapezoid AUC Glucose      0.0226047     0.0054895               0.0135907
# Corrected AUC Glucose      0.0226047     0.0054895               0.0135907
#
#                         Average Fasting C peptide Stumvoll First Phase  \
# AUC Glucose                             0.0302967             0.116405
# Average Fasting Glucose                 0.0464538             0.123894
# HOMA ISI                                 0.360802               0.1897
# Matsuda index                            0.323713             0.257835
# OGIS                                     0.213577           0.00623012
# Trapezoid AUC Glucose                   0.0355408             0.113281
# Corrected AUC Glucose                   0.0355408             0.113281
#
#                         Stumvoll Second Phase    HOMA IR      IGI 30  \
# AUC Glucose                         0.0905155  0.0495611    0.224189
# Average Fasting Glucose             0.0993243   0.424531    0.113337
# HOMA ISI                             0.212761   0.696949    0.027058
# Matsuda index                          0.2908   0.653807   0.0368279
# OGIS                                0.0121801   0.271961  0.00473018
# Trapezoid AUC Glucose               0.0858327  0.0492153    0.240307
# Corrected AUC Glucose               0.0858327  0.0492153    0.240307
#
#                          IGI Cpept        CPRI        PCPRI  \
# AUC Glucose               0.351821  0.00204812    0.0569804
# Average Fasting Glucose   0.187611   0.0203489    0.0745131
# HOMA ISI                 0.0444929    0.227965  5.02673e-05
# Matsuda index             0.057113    0.227182     0.017233
# OGIS                     0.0790912   0.0664625    0.0184654
# Trapezoid AUC Glucose     0.405197  0.00138577    0.0569804
# Corrected AUC Glucose     0.405197  0.00138577    0.0569804
#
#                         Trapezoid AUC Insuline Trapezoid AUC C peptide  \
# AUC Glucose                          0.0222676              0.00285077
# Average Fasting Glucose              0.0230515               0.0452687
# HOMA ISI                              0.363711               0.0123691
# Matsuda index                         0.591571               0.0907496
# OGIS                                  0.356655               0.0606581
# Trapezoid AUC Glucose                0.0210171              0.00230631
# Corrected AUC Glucose                0.0210171              0.00230631
#
#                         Corrected AUC Insuline
# AUC Glucose                          0.0194589
# Average Fasting Glucose              0.0210548
# HOMA ISI                              0.358683
# Matsuda index                         0.591516
# OGIS                                  0.337662
# Trapezoid AUC Glucose                0.0198065
# Corrected AUC Glucose                0.0198065

# %% [markdown]
# # Here we have a heatmap of R-squared value for a log relationship.
# It's centered around 0.2

# %%
import seaborn as sns
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(rsquare_df.values.tolist(), yticklabels=rsquare_df.index, xticklabels=rsquare_df.columns, 
            vmin=0, vmax=1, center=0.2, cmap=cmap, linewidths=.1)
plt.show()

# %% [markdown]
# # Spearman correlation
#
# Spearman have for advantage to be able to capture logarythmic relationships
#
# Take this example (taken from https://blog.bigml.com/2015/09/21/looking-for-connections-in-your-data-correlation-coefficients/)
#
# With p being pearson and s being spearman correlation coefficient (not squared)
#
# ![ascombe quartet](image/anscombe.png)

# %%
from analysis_script import spearman_p_value_DataFrame
spearman_p_value, corrspearman = spearman_p_value_DataFrame(ins_db[Ins_indexes])

# %%
corrspearman.drop(index = sec_indices, inplace = True)
corrspearman.drop(columns = sensitivity_indices, inplace = True)
corrspearman.drop(index = ['HOMA IR'], inplace = True)

# %%
corrspearman
# Out:
#                         AUC Insuline AUC C peptide Average Fasting Insulin  \
# AUC Glucose                 0.197008     0.0427452                 0.16838
# Average Fasting Glucose    -0.130488     -0.227377                0.164723
# HOMA ISI                   -0.618969     -0.271241               -0.969318
# Matsuda index              -0.646897     -0.259309               -0.795367
# OGIS                       -0.312893    -0.0438811                -0.37264
# Trapezoid AUC Glucose       0.193555     0.0746512                0.176248
# Corrected AUC Glucose       0.194187     0.0748252                0.176486
#
#                         Average Fasting C peptide Stumvoll First Phase  \
# AUC Glucose                              0.195479            -0.154503
# Average Fasting Glucose                   0.19417            -0.220993
# HOMA ISI                                 -0.64965            -0.410927
# Matsuda index                           -0.492308            -0.323864
# OGIS                                    -0.326923             0.146897
# Trapezoid AUC Glucose                    0.213704            -0.151837
# Corrected AUC Glucose                    0.213942            -0.151486
#
#                         Stumvoll Second Phase   HOMA IR     IGI 30  IGI Cpept  \
# AUC Glucose                         -0.126225  0.324588   -0.30444  -0.346376
# Average Fasting Glucose             -0.208926  0.393586  -0.247139  -0.347743
# HOMA ISI                            -0.427316 -0.909091  -0.199956  0.0888549
# Matsuda index                       -0.343837 -0.725262 -0.0966783    0.16049
# OGIS                                 0.129283 -0.385664   0.273427   0.345586
# Trapezoid AUC Glucose               -0.121898  0.336083  -0.309859  -0.371945
# Corrected AUC Glucose               -0.121547  0.336189  -0.309615  -0.372159
#
#                               CPRI      PCPRI Trapezoid AUC Insuline  \
# AUC Glucose               0.092418  -0.128017               0.189534
# Average Fasting Glucose -0.0311301  -0.196421              -0.135123
# HOMA ISI                 -0.473951 -0.0517045              -0.612325
# Matsuda index            -0.348164 -0.0355769              -0.650699
# OGIS                    -0.0729895   0.170017              -0.315122
# Trapezoid AUC Glucose     0.107715 -0.0752194               0.186519
# Corrected AUC Glucose     0.108392 -0.0749563                0.18715
#
#                         Trapezoid AUC C peptide Corrected AUC Insuline
# AUC Glucose                           0.0577148               0.181143
# Average Fasting Glucose               -0.206718              -0.140501
# HOMA ISI                              -0.295192              -0.612762
# Matsuda index                          -0.29458              -0.652098
# OGIS                                 -0.0673077              -0.316871
# Trapezoid AUC Glucose                 0.0905823               0.179176
# Corrected AUC Glucose                 0.0907343               0.179808

# %%
import seaborn as sns
sns.heatmap(corrspearman.values.tolist(), yticklabels=corrspearman.index, xticklabels=corrspearman.columns, 
            vmin=-1, vmax=1, center=0, cmap=cmap, linewidths=.1)
plt.show()

# %%
def lineareg(df, x, y):
    df = df[[x,y]].dropna()
    slope, intercept, r_value, d, e = scipy.stats.linregress(df[x], df[y])
    sns.lmplot(x=x, y=y, data=df)
    legend = 'y = '+str(round(slope,2))+'ln(x) + '+str(round(intercept, 2))+'\n'+'R**2 = '+str(round(r_value**2,4))
    x_box_coor = plt.gca().get_xlim()[1] - plt.gca().get_xlim()[1]/3
    y_box_coor = plt.gca().get_ylim()[1] - plt.gca().get_ylim()[1] / 6
    plt.gca().text(x_box_coor, y_box_coor, legend, style='italic',
            bbox={'facecolor': 'white', 'alpha': 1, 'pad': 10, 'lw':10})

lineareg(ins_db, 'Average Fasting Insulin', 'Average Fasting C peptide')
plt.show()
# Out:
# C:\Users\Daph\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# I want to do correlation with the maximum of data possible.
from scipy import stats
lists = [Ins_indexes,OGTT_ins, OGTT_cpept, OGTT_glu]

def get_good_datas(lists, a):
    if a in lists[1]:
        return ins_db[a]
    elif a in lists[2]:
        return cpept_db[a]
    else:
        return glu_db[a]
    
def correlator(df, lists, corr='spearman'):
    p_value_df = pd.DataFrame(columns = df.columns, index= df.columns)
    corrdf = pd.DataFrame(columns = df.columns, index= df.columns)
    
    big_list = lists[0]
    for a in big_list:
        for b in big_list:
            if a == b:
                p_value_df.loc[[a], [b]] = 1
                corrdf.loc[[a], [b]] = 1
            else:
                dummy_df = pd.concat([get_good_datas(lists, a),get_good_datas(lists, b)], axis=1,sort=False).dropna()
                _thearray = np.column_stack((dummy_df[a].tolist(), dummy_df[b].tolist()))
                r, p = stats.spearmanr(_thearray)
                p_value_df.loc[[a], [b]] = p
                corrdf.loc[[a], [b]] = r
    return p_value_df, corrdf

blih, bluh = correlator(final_db[Ins_indexes], lists)

# %%
bluh.drop(index = sec_indices, inplace = True)
bluh.drop(columns = sensitivity_indices, inplace = True)
bluh.drop(index = ['HOMA IR'], inplace = True)
import seaborn as sns
sns.heatmap(bluh.values.tolist(), yticklabels=bluh.index, xticklabels=bluh.columns, 
            vmin=-1, vmax=1, center=0, cmap=cmap, linewidths=.1)
plt.show()

# %%
bluh
# Out:
#                         AUC Insuline AUC C peptide Average Fasting Insulin  \
# AUC Glucose                 0.155526     -0.022215                0.136278
# Average Fasting Glucose    -0.158307     -0.306456                 0.11355
# HOMA ISI                   -0.597039     -0.103535               -0.974542
# Matsuda index              -0.803279     -0.255502               -0.913326
# OGIS                       -0.515699     -0.161883               -0.557569
# Trapezoid AUC Glucose       0.175168     -0.022215                0.140692
# Corrected AUC Glucose       0.175896    -0.0219412                0.140909
#
#                         Average Fasting C peptide Stumvoll First Phase  \
# AUC Glucose                              0.169405            -0.328852
# Average Fasting Glucose                  0.138208              -0.3404
# HOMA ISI                                -0.632152            -0.457324
# Matsuda index                           -0.569781            -0.525472
# OGIS                                    -0.447027            -0.060628
# Trapezoid AUC Glucose                    0.180446             -0.30241
# Corrected AUC Glucose                    0.180684             -0.30201
#
#                         Stumvoll Second Phase   HOMA IR    IGI 30 IGI Cpept  \
# AUC Glucose                         -0.294795   0.23384 -0.528273 -0.710894
# Average Fasting Glucose             -0.327228  0.291303  -0.38626 -0.519737
# HOMA ISI                             -0.47541        -1 -0.221682  0.153315
# Matsuda index                       -0.548488 -0.922105 -0.260074  0.152973
# OGIS                               -0.0830231 -0.644068  0.118878  0.318391
# Trapezoid AUC Glucose               -0.268671   0.24025 -0.503141 -0.710441
# Corrected AUC Glucose               -0.268271  0.240385 -0.502858 -0.710721
#
#                               CPRI       PCPRI Trapezoid AUC Insuline  \
# AUC Glucose             -0.0365068   -0.275089               0.146913
# Average Fasting Glucose  -0.202869   -0.355337              -0.163547
# HOMA ISI                 -0.506293   0.0228298              -0.589685
# Matsuda index            -0.475284  -0.0989177              -0.792914
# OGIS                     -0.218387 -0.00862764              -0.492811
# Trapezoid AUC Glucose   -0.0217217   -0.275089               0.167311
# Corrected AUC Glucose   -0.0209773   -0.274695               0.168039
#
#                         Trapezoid AUC C peptide Corrected AUC Insuline
# AUC Glucose                          0.00721133               0.140215
# Average Fasting Glucose               -0.271414              -0.166872
# HOMA ISI                              -0.143795              -0.589887
# Matsuda index                         -0.301709              -0.795875
# OGIS                                  -0.198475              -0.509086
# Trapezoid AUC Glucose                0.00721133               0.162174
# Corrected AUC Glucose                0.00745044               0.162902
